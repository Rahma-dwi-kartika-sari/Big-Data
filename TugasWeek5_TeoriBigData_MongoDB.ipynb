# %%
# !pip install pymongo[srv]
# Out:
# ...
# WARNING: pymongo 4.15.1 does not provide the extra 'srv'
# ...

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://rahmaakrty_db_user:Rahmadwi.12@cluster1bigdata.y9vg3su.mongodb.net/")

db = client["sample_airbnb"]

collection = db["listingsAndReviews"]

# %%
query_a = {"room_type": "Entire home/apt"}
results_a = list(collection.find(query_a).limit(5))

df_a = pd.DataFrame(results_a)[["_id", "name", "room_type",
                               "minimum_nights", "price"]]
df_a
# Out:
#         _id                                              name  \
# 0  10009999                      Horto flat with small garden
# 1  10047964                    Charming Flat in Downtown Moda
# 2  10059244  Ligne verte - à 15 min de métro du centre ville.
# 3  10083468                                 Be Happy in Porto
# 4  10091713  Surry Hills Studio - Your Perfect Base in Sydney
#
#          room_type minimum_nights   price
# 0  Entire home/apt              2  317.00
# 1  Entire home/apt              2  527.00
# 2  Entire home/apt              2   43.00
# 3  Entire home/apt              2   30.00
# 4  Entire home/apt             10  181.00

# %%
query_b = {"property_type": "House"}
results_b = list(collection.find(query_b).limit(5))

df_b = pd.DataFrame(results_b)[["_id", "name", "property_type",
                               "minimum_nights", "price"]]
df_b
# Out:
#         _id                                               name property_type  \
# 0  16253247  Gorgeous Remodeled Modern Home w/ Beach Across...         House
# 1  18616850    The Paddington Cottage | Sydney Eastern Suburbs         House
# 2  10109896                THE Place to See Sydney's FIREWORKS         House
# 3   1067052       Nani La 'Ao (A Beautiful Day) Upstairs Suite         House
# 4  14234561  Newly renovated studio in hip Bushwick near su...         House
#
#   minimum_nights   price
# 0              3  194.00
# 1              2  350.00
# 2              2  250.00
# 3              3   72.00
# 4              2  100.00

# %%
query_c = {"bed_type": "Real Bed"}
results_c = list(collection.find(query_c).limit(5))

df_c = pd.DataFrame(results_c)[["_id", "name","bed_type",
                               "minimum_nights", "price"]]
df_c
# Out:
#         _id                                              name  bed_type  \
# 0  10009999                      Horto flat with small garden  Real Bed
# 1  10047964                    Charming Flat in Downtown Moda  Real Bed
# 2  10059244  Ligne verte - à 15 min de métro du centre ville.  Real Bed
# 3  10083468                                 Be Happy in Porto  Real Bed
# 4  10091713  Surry Hills Studio - Your Perfect Base in Sydney  Real Bed
#
#   minimum_nights   price
# 0              2  317.00
# 1              2  527.00
# 2              2   43.00
# 3              2   30.00
# 4             10  181.00

# %%
query_d = {"cancellation_policy": "flexible"}
results_d = list(collection.find(query_d).limit(5))

df_d = pd.DataFrame(results_d)[["_id", "name", "cancellation_policy",
                               "minimum_nights", "price"]]
df_d
# Out:
#         _id                            name cancellation_policy  \
# 0  10009999    Horto flat with small garden            flexible
# 1  10047964  Charming Flat in Downtown Moda            flexible
# 2  10021707        Private Room in Bushwick            flexible
# 3  10096773       Easy 1 Bedroom in Chelsea            flexible
# 4  10030955     Apt Linda Vista Lagoa - Rio            flexible
#
#   minimum_nights   price
# 0              2  317.00
# 1              2  527.00
# 2             14   40.00
# 3              2  145.00
# 4              1  701.00

# %%
query_e = {"minimum_nights": {"$in": [2, "2"]}}
results_e = list(collection.find(query_e).limit(5))

if results_e:
    df_e = pd.DataFrame(results_e)[["_id", "name", "minimum_nights", "price"]]
    display(df_e)
else:
    print("Tidak ada data dengan minimum_nights = 2")
# Out:
#         _id                                              name minimum_nights  \
# 0  10009999                      Horto flat with small garden              2
# 1  10047964                    Charming Flat in Downtown Moda              2
# 2  10059244  Ligne verte - à 15 min de métro du centre ville.              2
# 3  10083468                                 Be Happy in Porto              2
# 4  10006546                           Ribeira Charming Duplex              2
#
#     price
# 0  317.00
# 1  527.00
# 2   43.00
# 3   30.00
# 4   80.00
